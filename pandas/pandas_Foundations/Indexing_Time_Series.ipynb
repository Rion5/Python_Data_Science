# %% [markdown]
# # Indexing Time Series
#
# ## Using pandas to read DateTime objects
#
# * read_csv() function
#     * Can read strings into datetime objects
#     * Need to specify **'parse_dates=True'**
# * ISO 8601 format
#     * yyyy-mm-dd hh:mm:ss

# %% [markdown]
#  **Parse Dates**

# %%
import pandas as pd
df = pd.read_csv('https://assets.datacamp.com/production/repositories/497/datasets/5b808399816c8dcb8eef08336595ef9b4eb22902/austin_airport_departure_data_2015_july.csv'
                 , header=10, index_col = 'Date (MM/DD/YYYY)', parse_dates =True)

# %% [markdown]
# ## Partial datetime string selection
#
# * Alternative formats:
#     * df.loc['July 5, 2015']
#     * df.loc['2015-July-5']
# * Whole month: df.loc['2015-7']
# * Whole year: df.loc['2015']
#
# ### Selecting whole month

# %%
july2015 = df.loc['2015-7']
july2015.head()
# Out:
#                     Carrier Code  Flight Number Tail Number  \
# Date (MM/DD/YYYY)
# 2015-07-01                    WN          103.0      N8607M
# 2015-07-01                    WN          144.0      N8609A
# 2015-07-01                    WN          178.0      N646SW
# 2015-07-01                    WN          232.0      N204WN
# 2015-07-01                    WN          238.0      N233LV
#
#                   Destination Airport  Scheduled Departure Time  \
# Date (MM/DD/YYYY)
# 2015-07-01                         MDW                    06:30
# 2015-07-01                         SAN                    20:55
# 2015-07-01                         ELP                    20:30
# 2015-07-01                         ATL                    05:45
# 2015-07-01                         DAL                    12:30
#
#                   Actual Departure Time  Scheduled Elapsed Time(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                        06:52                            165.0
# 2015-07-01                        20:50                            170.0
# 2015-07-01                        20:45                             90.0
# 2015-07-01                        05:49                            135.0
# 2015-07-01                        12:34                             55.0
#
#                    Actual Elapsed Time(Minutes)  Departure Delay(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                                147.0                      22.0
# 2015-07-01                                158.0                      -5.0
# 2015-07-01                                 80.0                      15.0
# 2015-07-01                                137.0                       4.0
# 2015-07-01                                 48.0                       4.0
#
#                   Wheels-off Time  Taxi-out Time(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                  07:01                     9.0
# 2015-07-01                  21:03                    13.0
# 2015-07-01                  20:55                    10.0
# 2015-07-01                  06:01                    12.0
# 2015-07-01                  12:41                     7.0
#
#                    DelayCarrier(Minutes)  DelayWeather(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                           0.0                    0.0
# 2015-07-01                           0.0                    0.0
# 2015-07-01                           0.0                    0.0
# 2015-07-01                           0.0                    0.0
# 2015-07-01                           0.0                    0.0
#
#                    DelayNational Aviation System(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                                            0.0
# 2015-07-01                                            0.0
# 2015-07-01                                            0.0
# 2015-07-01                                            0.0
# 2015-07-01                                            0.0
#
#                    DelaySecurity(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                            0.0
# 2015-07-01                            0.0
# 2015-07-01                            0.0
# 2015-07-01                            0.0
# 2015-07-01                            0.0
#
#                    DelayLate Aircraft Arrival(Minutes)  Unnamed: 17
# Date (MM/DD/YYYY)
# 2015-07-01                                         0.0          NaN
# 2015-07-01                                         0.0          NaN
# 2015-07-01                                         0.0          NaN
# 2015-07-01                                         0.0          NaN
# 2015-07-01                                         0.0          NaN

# %% [markdown]
# ### Slicing using dates / times

# %%
df.loc['2015-07-05' : '2015-07-10'].head()
# Out:
#                     Carrier Code  Flight Number Tail Number  \
# Date (MM/DD/YYYY)
# 2015-07-05                    WN          144.0      N8651A
# 2015-07-05                    WN          178.0      N7703A
# 2015-07-05                    WN          238.0      N751SW
# 2015-07-05                    WN          285.0      N528SW
# 2015-07-05                    WN          311.0      N489WN
#
#                   Destination Airport  Scheduled Departure Time  \
# Date (MM/DD/YYYY)
# 2015-07-05                         SAN                    20:55
# 2015-07-05                         ELP                    20:30
# 2015-07-05                         DAL                    12:30
# 2015-07-05                         DAL                    09:25
# 2015-07-05                         MDW                    15:05
#
#                   Actual Departure Time  Scheduled Elapsed Time(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-05                        21:10                            170.0
# 2015-07-05                        20:39                             90.0
# 2015-07-05                        12:33                             55.0
# 2015-07-05                        09:24                             55.0
# 2015-07-05                        15:34                            150.0
#
#                    Actual Elapsed Time(Minutes)  Departure Delay(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-05                                160.0                      15.0
# 2015-07-05                                 84.0                       9.0
# 2015-07-05                                 51.0                       3.0
# 2015-07-05                                 50.0                      -1.0
# 2015-07-05                                143.0                      29.0
#
#                   Wheels-off Time  Taxi-out Time(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-05                  21:20                    10.0
# 2015-07-05                  20:48                     9.0
# 2015-07-05                  12:41                     8.0
# 2015-07-05                  09:32                     8.0
# 2015-07-05                  15:42                     8.0
#
#                    DelayCarrier(Minutes)  DelayWeather(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-05                           0.0                    0.0
# 2015-07-05                           0.0                    0.0
# 2015-07-05                           0.0                    0.0
# 2015-07-05                           0.0                    0.0
# 2015-07-05                          22.0                    0.0
#
#                    DelayNational Aviation System(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-05                                            0.0
# 2015-07-05                                            0.0
# 2015-07-05                                            0.0
# 2015-07-05                                            0.0
# 2015-07-05                                            0.0
#
#                    DelaySecurity(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-05                            0.0
# 2015-07-05                            0.0
# 2015-07-05                            0.0
# 2015-07-05                            0.0
# 2015-07-05                            0.0
#
#                    DelayLate Aircraft Arrival(Minutes)  Unnamed: 17
# Date (MM/DD/YYYY)
# 2015-07-05                                         0.0          NaN
# 2015-07-05                                         0.0          NaN
# 2015-07-05                                         0.0          NaN
# 2015-07-05                                         0.0          NaN
# 2015-07-05                                         0.0          NaN

# %% [markdown]
# ### Converting strings to datetime
#
# The pandas .to_datetime() function can convert strings in ISO 8601 format to pandas datetime objects

# %%
july_11_2015 = pd.to_datetime(['2015-7-11'])

# %% [markdown]
# #### Reindexing DataFrames

# %%
# df.reindex(july_11_2015)

# %% [markdown]
# ### Filling missing values

# %%
# ffill = forward fill, bfill = back fill
# df.reindex(july_11_2015, method='ffill')
